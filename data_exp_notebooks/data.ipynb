# %%
import os
import shutil
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from wordcloud import WordCloud
from textblob import TextBlob
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.decomposition import LatentDirichletAllocation, TruncatedSVD
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# %% [markdown]
# ### Collect Data

# %%
neg_vids_dir = '/home/davendra/ml-prj/deepfake_extractions/neg_vids/Negative_Deepfake_temp_dataset'
neg_train_csv = '/home/davendra/ml-prj/deepfake_extractions/negative/training.csv'
neg_val_csv = '/home/davendra/ml-prj/deepfake_extractions/negative/validation.csv'
neg_test_csv = '/home/davendra/ml-prj/deepfake_extractions/negative/test.csv'

pos_vids_dir = '/home/davendra/ml-prj/deepfake_extractions/pos_vids/Deepfake_temp_dataset'
pos_train_csv = '/home/davendra/ml-prj/deepfake_extractions/positive/training.csv'
pos_val_csv = '/home/davendra/ml-prj/deepfake_extractions/positive/validation.csv'
pos_test_csv = '/home/davendra/ml-prj/deepfake_extractions/positive/test.csv'

train_dir = '/home/davendra/ml-prj/deepfake_extractions/train'
val_dir = '/home/davendra/ml-prj/deepfake_extractions/val'
test_di = '/home/davendra/ml-prj/deepfake_extractions/test'

# %%
# Collect all data into dataframes

# Positive
pos_train_df = pd.read_csv(pos_train_csv)
pos_val_df = pd.read_csv(pos_val_csv)
pos_test_df = pd.read_csv(pos_test_csv)

# Negative
neg_train_df = pd.read_csv(neg_train_csv)
neg_val_df = pd.read_csv(neg_val_csv)
neg_test_df = pd.read_csv(neg_test_csv)

# %% [markdown]
# ### Display Negative Data

# %%
display(neg_train_df)
print(f'Size of Negative Train Data: {len(neg_train_df)}')
# Out:
#         video_id                                              title  \
# 0    NIAnOmqK2k0  Yikes! Joe Biden On Why He Was So Irresponsibl...
# 1    KDiUF9FG70Y         In the Dark | Joe Biden For President 2020
# 2    QXYzsFfvpLg  "The future is yours" Joe Biden's message to a...
# 3    PNKWjqW8kvI  Biden Gets Confused (Again): "Middle Class Did...
# 4    iKKRU3ALjb0        Republicans want a national ban on abortion
# ..           ...                                                ...
# 318  CQ-qQIKWYBw  “I Want A Safe America…” | Joe Biden For Presi...
# 319  rs3vQ49mfrY  "I'm IGN" #KeanuReeves #johnwick #redcarpet #m...
# 320  T-9nFXNAE2I  I plan to work before the government is formed...
# 321  yJp5bEEO8uo                    Elon Musk warns as about AI💫🔥👌🏻
# 322  1qZORdDEc3Q  PM Netanyahu: Today I'm going to make an unpre...
#
#                                            description  \
# 0                                                  NaN
# 1    Join our campaign: http://www.joebiden.comFoll...
# 2    Joe Biden wants to make sure younger generatio...
# 3                             Comments made on 4/17/24
# 4    Follow Joe!Joe’s Twitter: https://twitter.com/...
# ..                                                 ...
# 318  Donald Trump looks at this violence and sees a...
# 319                                                NaN
# 320  During an interview with the news agency ANI, ...
# 321                                                NaN
# 322  Today I'm going to make an unprecedented offer...
#
#                                              url  \
# 0    https://www.youtube.com/watch?v=NIAnOmqK2k0
# 1    https://www.youtube.com/watch?v=KDiUF9FG70Y
# 2    https://www.youtube.com/watch?v=QXYzsFfvpLg
# 3    https://www.youtube.com/watch?v=PNKWjqW8kvI
# 4    https://www.youtube.com/watch?v=iKKRU3ALjb0
# ..                                           ...
# 318  https://www.youtube.com/watch?v=CQ-qQIKWYBw
# 319  https://www.youtube.com/watch?v=rs3vQ49mfrY
# Out:
#        video_id                                              title  \
# 0   xAPIjhkXF-0        Tom Cruise gives the most epic answer ever.
# 1   VueoqsrV5bI  My decisions are neither meant to scare anyone...
# 2   WbZHZj2v05E  Tiranga guaranteed safe evacuation of Indians ...
# 3   zOh1-WHonds  Shehnaaz Kaur Gill at Lakme Fashion Week 😍💖📸 #...
# 4   zotkJwZ9PVY                             These are young adults
# ..          ...                                                ...
# 88  SsVXDDQaQhM         President Biden Announces 431,000 New Jobs
# 89  cKEZ4zlb7cU  North Korean leader Kim Jong Un is visibly emo...
# 90  54cNlElopjE  Donald Trump on how environmentally friendly J...
# 91  7-AAvESiRHU                      We stand with Israel. #shorts
# 92  tqdSnr_0IvA  President Biden Announces Additional $800 Mill...
#
#                                           description  \
# 0                                                 NaN
# 1   During an interview with the news agency ANI, ...
# 2   During an interview with the news agency ANI, ...
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 88  President Biden speaks to the American people ...
# 89  North Korean leader Kim Jong Un appears to cry...
# 90  #meme #memes #donaldtrump #trump #shorts Donal...
# 91            There’s no justification for terrorism.
# 92  President Biden announced an $800M assistance ...
#
#                                             url  \
# 0   https://www.youtube.com/watch?v=xAPIjhkXF-0
# 1   https://www.youtube.com/watch?v=VueoqsrV5bI
# 2   https://www.youtube.com/watch?v=WbZHZj2v05E
# 3   https://www.youtube.com/watch?v=zOh1-WHonds
# 4   https://www.youtube.com/watch?v=zotkJwZ9PVY
# ..                                          ...
# 88  https://www.youtube.com/watch?v=SsVXDDQaQhM
# 89  https://www.youtube.com/watch?v=cKEZ4zlb7cU
# 90  https://www.youtube.com/watch?v=54cNlElopjE
# 91  https://www.youtube.com/watch?v=7-AAvESiRHU
# 92  https://www.youtube.com/watch?v=tqdSnr_0IvA
#
#                                              comments  label
# 0   Over +150,000 views!  Thank you 🙌  <br><br>Wat...      0
# 1   Very nice and jay Shri Krishna radhe and I lov...      0
# 2   Fekuman ne war ruka di. Ab Petrol, diesel, Cng...      0
# 3   Shehnaz ❤😊<sep>Real❤<sep>❤❤❤❤❤<sep>Pure soul b...      0
# 4   I use to umpire baseball and this one guy was ...      0
# ..                                                ...    ...
# 88  &quot;I&#39;ve thrown out these numbers, there...      0
# 89  Free North Korea<sep>Dx satalite message... il...      0
# 90  Like and share the video if you love President...      0
# 91  Youtube, why are you paranoid of my comments, ...      0
# 92  In Europe there is not enough production capac...      0
#
# [93 rows x 6 columns]
# Size of Negative Test Data: 93

# %% [markdown]
# ### Display Positive Data

# %%
display(pos_train_df)
print(f'Size of Positive Train Data: {len(pos_train_df)}')
# Out:
#         video_id                                              title  \
# 0    KabnUV5luJ8     Cersei Lannister is Melania Trump [ Deepfake ]
# 1    iGiwNf_bor4  Jason Momoa Justice League edit because Amber ...
# 2    6aSoP0mDM0g         Obama ACTUALLY Does the Obamehameha (REAL)
# 3    H_RFyF-tgZ4  DEEPFAKE | THOR Selling Phones in INDIA | Aven...
# 4    E_hjqpXgUO0   Donald Trump gets all Fat and Sassy [ Deepfake ]
# ..           ...                                                ...
# 299  B68GxCrs5rI  Problem Сhild / Macaulay Culkin (DeepFake) Tik...
# 300  OF2Hrq2aK5k             Presidential Tales: Kidnappers Shoes !
# 301  UkjmTzUZbdQ                      Flying Cars [RIFE AI Slow-Mo]
# 302  jxxzi4es0Ko  Ace Ventura / Ben Stiller (DeepFake) TikTok #S...
# 303  MQ8DQgAwXew              Jay Leno as Sean Hannity [ Deepfake ]
#
#                                            description  \
# 0    Enjoy :) And PLEASE Like & Subscribe if you wa...
# 1    Due to Amber Heard maybe being fired from Aqua...
# 2    Sleepy Joe's Biden Blast is one thing.Big Mike...
# 3    Deepfake | Thor at Mobile Shop in India 😂😂What...
# 4    ENJOY!Check out our community forums:https://o...
# ..                                                 ...
# 299  Do not click 😎 https://www.youtube.com/c/AnyFa...
# 300  Presidential Tales: Biden, Trump, Clinton, Oba...
# 301  This a test of new neural network called RIFE,...
# 302  Do not click 😎  https://www.youtube.com/c/AnyF...
# 303  Enjoy :) And PLEASE Like & Subscribe if you wa...
#
#                                              url  \
# 0    https://www.youtube.com/watch?v=KabnUV5luJ8
# 1    https://www.youtube.com/watch?v=iGiwNf_bor4
# 2    https://www.youtube.com/watch?v=6aSoP0mDM0g
# 3    https://www.youtube.com/watch?v=H_RFyF-tgZ4
# 4    https://www.youtube.com/watch?v=E_hjqpXgUO0
# ..                                           ...
# 299  https://www.youtube.com/watch?v=B68GxCrs5rI
# 300  https://www.youtube.com/watch?v=OF2Hrq2aK5k
# 301  https://www.youtube.com/watch?v=UkjmTzUZbdQ
# 302  https://www.youtube.com/watch?v=jxxzi4es0Ko
# 303  https://www.youtube.com/watch?v=MQ8DQgAwXew
#
#                                               comments  label
# 0    Please name of the software ?<sep>Deep fake<se...      1
# 1    crazy <a href="UCkszU2WH9gy1mb0dV-11UJg/hcIfY5...      1
# 2    Now we need Trumps card to block the attacks a...      1
# 3    How do you guys not have millions of subscribe...      1
# 4              Same. 😒<sep>Lol the way the head moves.      1
# ..                                                 ...    ...
# 299                                                NaN      1
# 300  Funny! 👍<sep>That Blank expression of Biden af...      1
# 301  <a href="https://shutr.bz/3H7OcGG">https://shu...      1
# 302                                                NaN      1
# 303  OMFG...😂<sep>Now he looks like John Goodman lo...      1
#
# [304 rows x 6 columns]
# Size of Positive Train Data: 304

# %%
display(pos_val_df)
print(f'Size of Positive Val Data: {len(pos_val_df)}')
# Out:
#        video_id                                              title  \
# 0   zgX99Ne9mbI       What if politicians were teachers | DEEPFAKE
# 1   AcQdS9M7P5I                Ghost Caught On Traffic CCTV Camera
# 2   9J54CMpQO1A            Presidential Tales: My Wife Birthday...
# 3   pQGOJ5qPAS0  Get yourself Customised Synthetic Media Video ...
# 4   lDR2lmCO6iM                Scarlett Johansson eating Spaghetti
# 5   p89NkyNcpHo                     Ironman Recast - Michael Scott
# 6   v8uDCETeoj0            All in One #2 (DeepFake) TikTok #Shorts
# 7   0uGPxQHW4vY                        Spider-Man eating Spaghetti
# 8   4Qwyb-JZQuA  Men in Black / Kevin Hart (DeepFake) TikTok #S...
# 9   Xn1Tj_vHcjY                       THE THING starring Joe Biden
# 10  m6teLPZLMyI  C3PO's looks at his REAL FRIENDS before he die...
# 11  vyFzuGF_kmM  Kevin Spacey is back to acting - as Donald Tru...
# 12  jbvlVo8WLOU    Aladdin / Amber Heard (DeepFake) TikTok #Shorts
# 13  HCcIPLtDaeM  Donald Trump helps Elon Musk fire employees in...
# 14  320yMfXjHd4      Presidential Tales:  I Accidentally Swallowed
# 15  htYo_eAcwHQ           Presidential Tales: Pregnant Barbie Doll
print(f'Size of Positive Test Data: {len(pos_test_df)}')
# Out:
#        video_id                                              title  \
# 0   KvWL3zsR8p0  Transforming AI real time Translation with Voi...
# 1   Xj0vm2n90SU  The Hangover /Chris Evans (DeepFake) TikTok #S...
# 2   0M7XvqtWUWc  Interview with the Vampire / Robert Pattinson ...
# 3   8eMnD0QSZqs  Donald Trump with Mike "Kathy Griffin" Pence [...
# 4   Hli_IGInsZc                                   Terminator T-800
# ..          ...                                                ...
# 83  0nNb2s7YdnE                           Adele CAN'T SING - FUNNY
# 84  iCERbfzpdZE                               Star Trek Rap Battle
# 85  pvRzoYi2FSc  Jim Carrey as Joe Biden giving a speech for th...
# 86  tDAToEnJEY8                J'adore starring Mr Bean [DeepFake]
# 87  kFwq7fmj6DE  Disney Star Wars Original Trilogy Special Edition
#
#                                           description  \
# 0   🚀Recently, Prime Minister Modi utilized an AI ...
# 1   Do not click 😎  https://www.youtube.com/c/AnyF...
# 2   Do not click 😎  https://www.youtube.com/c/AnyF...
# 3   Nice makeup job Mike!ENJOY!Check out our commu...
# 4   This video has been created by an AI for exper...
# ..                                                ...
# 83  Funny edit Adele not being able to sing well w...
# 84  Star Trek movie rap battle James T Kirk & Doct...
# 85  Enjoy :) And PLEASE Like & Subscribe if you wa...
# 86  Discover the new J'adore Absolu deepfake film ...
# 87  Disney makes a special edition of Star Wars th...
#
#                                             url  \
# 0   https://www.youtube.com/watch?v=KvWL3zsR8p0
# 1   https://www.youtube.com/watch?v=Xj0vm2n90SU
# 2   https://www.youtube.com/watch?v=0M7XvqtWUWc
# 3   https://www.youtube.com/watch?v=8eMnD0QSZqs
# 4   https://www.youtube.com/watch?v=Hli_IGInsZc
# ..                                          ...
# 83  https://www.youtube.com/watch?v=0nNb2s7YdnE
# 84  https://www.youtube.com/watch?v=iCERbfzpdZE
# 85  https://www.youtube.com/watch?v=pvRzoYi2FSc
# 86  https://www.youtube.com/watch?v=tDAToEnJEY8
# 87  https://www.youtube.com/watch?v=kFwq7fmj6DE
#
#                                              comments  label
# 0   <b>How to make your own voice clone like this ...      1
# 1                                                 NaN      1
# 2                                                 NaN      1
# 3   That was so disturbing dude lol. It didn&#39;t...      1
# 4   Creepinator T-800<sep>Does anyone know what ai...      1
# ..                                                ...    ...
# 83  I can&#39;t monetize this video.  If you like ...      1
# 84  Dude this video is soooo damn hilarious… I can...      1
# 85  2 slimeballs in one... yey!<sep>lol<sep>Grief ...      1
# 86  <a href="https://shutr.bz/3H7OcGG">https://shu...      1
# 87  Hilarious!<sep>Please, don&#39;t give Disney i...      1
#
# [88 rows x 6 columns]
# Size of Positive Test Data: 88

# %% [markdown]
# ### Some Cleaning Functions

# %%
import re
import string
import emoji

def clean_text(text):
    # Convert input to string
    text = str(text)
    
    # Remove <sep> tags
    text = re.sub(r'<sep>', ' ', text)
    
    # Remove HTML tags
    text = re.sub(r'<[^>]*>', ' ', text)
    
    # Remove URLs
    text = re.sub(r'http\S+', ' ', text)
    
    # Remove punctuation marks
    text = text.translate(str.maketrans(' ', ' ', string.punctuation))
    
    # Remove emojis
    text = emoji.replace_emoji(text, replace='')
    
    # Convert text to lowercase
    text = text.lower()
    
    # Remove extra whitespace
    text = text.strip()
    text = re.sub(r'\s+', ' ', text)
    
    return text

# %%
text = '<sep>Lol the way the head moves'
clean_text(text)
# Out:
# 'lol the way the head moves'

# %% [markdown]
# ### Youtube Scraping

# %%
# api_key = 'AIzaSyDyCuxE5dBSUkUypRMU4OojLn__g7-Wujo'
# videoID = ''
# get_comments(apikey=api_key, videoID=videoID)

# %%
from googleapiclient.discovery import build

def get_comments(apikey=None, videoID=None):
    # Replace with your actual API key
    API_KEY = apikey

    # Create a YouTube Data API client
    youtube = build('youtube', 'v3', developerKey=API_KEY)

    # Replace with the ID of the video you want to retrieve comments from
    VIDEO_ID = videoID

    # Retrieve the comments for the video
    response = youtube.commentThreads().list(
        part='snippet',
        videoId=VIDEO_ID,
        textFormat='plainText'
    ).execute()

    # Process the comments
    for item in response['items']:
        comment = item['snippet']['topLevelComment']['snippet']
        author = comment['authorDisplayName']
        text = comment['textDisplay']
        print(f'Author: {author}')
        print(f'Comment: {text}')
        print('---')

    # Check if there are more pages of comments
    while 'nextPageToken' in response:
        response = youtube.commentThreads().list(
            part='snippet',
            videoId=VIDEO_ID,
            pageToken=response['nextPageToken'],
            textFormat='plainText'
        ).execute()

        # Process the comments on the next page
        for item in response['items']:
            comment = item['snippet']['topLevelComment']['snippet']
            author = comment['authorDisplayName']
            text = comment['textDisplay']
            print(f'Author: {author}')
            print(f'Comment: {text}')
            print('---')

# %% [markdown]
# ### Cleaning Positives

# %%
# Create a new DataFrame with the cleaned text for positive
cleaned_pos_train_df = pd.DataFrame(columns=['video_id', 'title', 'description', 'url', 'comments', 'label'])
cleaned_pos_val_df = pd.DataFrame(columns=['video_id', 'title', 'description', 'url', 'comments', 'label'])
cleand_pos_test_df = pd.DataFrame(columns=['video_id', 'title', 'description', 'url', 'comments', 'label'])

# %%
cleaned_pos_train_df['video_id'] = pos_train_df['video_id']
cleaned_pos_train_df['url'] = pos_train_df['url']
cleaned_pos_train_df['label'] = pos_train_df['label']
cleaned_pos_train_df['title'] = pos_train_df['title'].apply(clean_text)
cleaned_pos_train_df['description'] = pos_train_df['description'].apply(clean_text)
cleaned_pos_train_df['comments'] = pos_train_df['comments'].apply(clean_text)

# %%
display(cleaned_pos_train_df)
print(f'Size of Cleaned Positive Train Data: {len(cleaned_pos_train_df)}')
# Out:
#         video_id                                              title  \
# 0    KabnUV5luJ8         cersei lannister is melania trump deepfake
# 1    iGiwNf_bor4  jason momoa justice league edit because amber ...
# 2    6aSoP0mDM0g           obama actually does the obamehameha real
# 3    H_RFyF-tgZ4     deepfake thor selling phones in india avengers
# 4    E_hjqpXgUO0       donald trump gets all fat and sassy deepfake
# ..           ...                                                ...
# 299  B68GxCrs5rI  problem сhild macaulay culkin deepfake tiktok ...
# 300  OF2Hrq2aK5k                presidential tales kidnappers shoes
# 301  UkjmTzUZbdQ                         flying cars rife ai slowmo
# 302  jxxzi4es0Ko     ace ventura ben stiller deepfake tiktok shorts
# 303  MQ8DQgAwXew                  jay leno as sean hannity deepfake
#
#                                            description  \
# 0    enjoy and please like subscribe if you want to...
# 1    due to amber heard maybe being fired from aqua...
# 2    sleepy joes biden blast is one thingbig mikes ...
# 3    deepfake thor at mobile shop in india what if ...
# 4    enjoycheck out our community forums helping th...
# ..                                                 ...
# 299  do not click a help of neural networks anyone ...
# 300  presidential tales biden trump clinton obama p...
# 301  this a test of new neural network called rife ...
# 302  do not click a help of neural networks anyone ...
# 303  enjoy and please like subscribe if you want to...
#
#                                              url  \
# 0    https://www.youtube.com/watch?v=KabnUV5luJ8
# 1    https://www.youtube.com/watch?v=iGiwNf_bor4
# 2    https://www.youtube.com/watch?v=6aSoP0mDM0g
# 3    https://www.youtube.com/watch?v=H_RFyF-tgZ4
# 4    https://www.youtube.com/watch?v=E_hjqpXgUO0
# ..                                           ...
# 299  https://www.youtube.com/watch?v=B68GxCrs5rI
# 300  https://www.youtube.com/watch?v=OF2Hrq2aK5k
# 301  https://www.youtube.com/watch?v=UkjmTzUZbdQ
# 302  https://www.youtube.com/watch?v=jxxzi4es0Ko
# 303  https://www.youtube.com/watch?v=MQ8DQgAwXew
#
#                                               comments  label
# 0    please name of the software deep fake try putt...      1
# 1    crazy the way willem dafoe said lies made me l...      1
# 2    now we need trumps card to block the attacks a...      1
# 3    how do you guys not have millions of subscribe...      1
# 4                      same lol the way the head moves      1
# ..                                                 ...    ...
# 299                                                nan      1
# 300  funny that blank expression of biden after the...      1
# 301  unlock the power of stock footage today cool c...      1
# 302                                                nan      1
# 303  omfg now he looks like john goodman lol hilari...      1
#
# [304 rows x 6 columns]
# Size of Cleaned Positive Train Data: 304

# %%
cleaned_pos_val_df = pd.DataFrame(columns=['video_id', 'title', 'description', 'url', 'comments', 'label'])
cleaned_pos_val_df = pd.DataFrame(columns=['video_id', 'title', 'description', 'url', 'comments', 'label'])
cleaned_pos_val_df = pd.DataFrame(columns=['video_id', 'title', 'description', 'url', 'comments', 'label'])

cleaned_pos_val_df['video_id'] = pos_val_df['video_id']
cleaned_pos_val_df['url'] = pos_val_df['url']
cleaned_pos_val_df['label'] = pos_val_df['label']
cleaned_pos_val_df['title'] = pos_val_df['title'].apply(clean_text)
cleaned_pos_val_df['description'] = pos_val_df['description'].apply(clean_text)
cleaned_pos_val_df['comments'] = pos_val_df['comments'].apply(clean_text)

# %%
display(cleaned_pos_val_df)
print(f'Size of Cleaned Positive Val Data: {len(cleaned_pos_val_df)}')
# Out:
#        video_id                                              title  \
# 0   zgX99Ne9mbI         what if politicians were teachers deepfake
# 1   AcQdS9M7P5I                ghost caught on traffic cctv camera
# 2   9J54CMpQO1A                presidential tales my wife birthday
# 3   pQGOJ5qPAS0  get yourself customised synthetic media video ...
# 4   lDR2lmCO6iM                scarlett johansson eating spaghetti
# 5   p89NkyNcpHo                       ironman recast michael scott
# 6   v8uDCETeoj0                all in one 2 deepfake tiktok shorts
# 7   0uGPxQHW4vY                         spiderman eating spaghetti
# 8   4Qwyb-JZQuA     men in black kevin hart deepfake tiktok shorts
# 9   Xn1Tj_vHcjY                       the thing starring joe biden
# 10  m6teLPZLMyI  c3pos looks at his real friends before he dies...
# 11  vyFzuGF_kmM  kevin spacey is back to acting as donald trump...
# 12  jbvlVo8WLOU         aladdin amber heard deepfake tiktok shorts
# 13  HCcIPLtDaeM  donald trump helps elon musk fire employees in...
# 14  320yMfXjHd4        presidential tales i accidentally swallowed
# 15  htYo_eAcwHQ            presidential tales pregnant barbie doll
# 16  8sCPZlJd4bk  deepfake ayushman khurrana as professor money ...
# 2   so i bought her nothing so fake the movement o...      1
# 3                                    love yr work man      1
# 4   she is beautiful and saucy everyone must eat s...      1
# 5   quothello this is micheal scott i have an idea...      1
# 6                                                 nan      1
# 7   “hey get away from my pasta” bro looks more th...      1
# 8                                                 nan      1
# 9   when you read the news all day and the world i...      1
# 10  if this doesn39t make you feel something insid...      1
# 11  who is that lol he looks asian now lmao the be...      1
# 12                                                nan      1
# 13  getting paid for nothing you can39t blame elon...      1
# 14  a script to die for it was actualy funny excep...      1
# 15  so many people hate gw bush but i would really...      1
# 16  editing king can u stream live or tell more ab...      1
# 17                                                nan      1
# 18  that is michael backson wait this actually mak...      1
# 19  smh lol can anyone explain the salad dressing ...      1
# 20  unlock the power of stock footage today i need...      1
# 21                                                nan      1
# 22  katrina ke deepfake kabhi achhe nahi bante vin...      1
# 23  هههههههخ this makes for some great entertainme...      1
# 24  to the person who made this you are awesome th...      1
# 25                                                nan      1
# 26  me when i was 12 wondering what i39d look like...      1
# 27  donald trump president eeuu rumbo a la preside...      1
# 28  this is gold and i39m rich dear putin and patr...      1
# 29  plot twist akatosh and corn pop are the same p...      1
# 30  can39t wait for these 2 traitors to be prosecu...      1
# 31  wonderful rap take that jack awasome u will be...      1
# 32  fire joe for putting s pen in a food sleepy jo...      1
# 33  still would take that trump over old joe any d...      1
# 34  我真的聽不懂英文 the fake lines from ai are too real s...      1
# 35  you gonna post anything else man dude duplicat...      1
# 36  gw liked the biden joke the secret service is ...      1
# 37  026 damn man chris rock better stay away from ...      1
# 38  unlock the power of stock footage today she39s...      1
# 39                                                nan      1
# 40  the kid looks like actor peter gerety from sne...      1
# 41  bro kept trying to turn into a helicoprion at ...      1
# 42  unlock the power of stock footage today he loo...      1
# Size of Cleaned Positive Val Data: 43

# %%
cleaned_pos_test_df = pd.DataFrame(columns=['video_id', 'title', 'description', 'url', 'comments', 'label'])
cleaned_pos_test_df = pd.DataFrame(columns=['video_id', 'title', 'description', 'url', 'comments', 'label'])
cleaned_pos_test_df = pd.DataFrame(columns=['video_id', 'title', 'description', 'url', 'comments', 'label'])

cleaned_pos_test_df['video_id'] = pos_test_df['video_id']
cleaned_pos_test_df['url'] = pos_test_df['url']
cleaned_pos_test_df['label'] = pos_test_df['label']
cleaned_pos_test_df['title'] = pos_test_df['title'].apply(clean_text)
cleaned_pos_test_df['description'] = pos_test_df['description'].apply(clean_text)
cleaned_pos_test_df['comments'] = pos_test_df['comments'].apply(clean_text)

# %%
display(cleaned_pos_test_df)
print(f'Size of Cleaned Positive Test Data: {len(cleaned_pos_test_df)}')
# Out:
#        video_id                                              title  \
# 0   KvWL3zsR8p0  transforming ai real time translation with voi...
# 1   Xj0vm2n90SU    the hangover chris evans deepfake tiktok shorts
# 2   0M7XvqtWUWc  interview with the vampire robert pattinson de...
# 3   8eMnD0QSZqs  donald trump with mike kathy griffin pence dee...
# 4   Hli_IGInsZc                                    terminator t800
# ..          ...                                                ...
# 83  0nNb2s7YdnE                              adele cant sing funny
# 84  iCERbfzpdZE                               star trek rap battle
# 85  pvRzoYi2FSc  jim carrey as joe biden giving a speech for th...
# 86  tDAToEnJEY8                   jadore starring mr bean deepfake
# 87  kFwq7fmj6DE  disney star wars original trilogy special edition
#
#                                           description  \
# 0   recently prime minister modi utilized an ai to...
# 1   do not click a help of neural networks anyone ...
# 2   do not click a help of neural networks anyone ...
# 3   nice makeup job mikeenjoycheck out our communi...
# 4   this video has been created by an ai for exper...
# ..                                                ...
# 83  funny edit adele not being able to sing well w...
# 84  star trek movie rap battle james t kirk doctor...
# 85  enjoy and please like subscribe if you want to...
# 86  discover the new jadore absolu deepfake film s...
# 87  disney makes a special edition of star wars th...
#
#                                             url  \
# 0   https://www.youtube.com/watch?v=KvWL3zsR8p0
# 1   https://www.youtube.com/watch?v=Xj0vm2n90SU
# 2   https://www.youtube.com/watch?v=0M7XvqtWUWc
# 3   https://www.youtube.com/watch?v=8eMnD0QSZqs
# 4   https://www.youtube.com/watch?v=Hli_IGInsZc
# ..                                          ...
# 83  https://www.youtube.com/watch?v=0nNb2s7YdnE
# 84  https://www.youtube.com/watch?v=iCERbfzpdZE
# 85  https://www.youtube.com/watch?v=pvRzoYi2FSc
# 86  https://www.youtube.com/watch?v=tDAToEnJEY8
# 87  https://www.youtube.com/watch?v=kFwq7fmj6DE
#
#                                              comments  label
# 0   how to make your own voice clone like this ple...      1
# 1                                                 nan      1
# 2                                                 nan      1
# 3   that was so disturbing dude lol it didn39t loo...      1
# 4   creepinator t800 does anyone know what ai mode...      1
# ..                                                ...    ...
# 83  i can39t monetize this video if you like to he...      1
# 84  dude this video is soooo damn hilarious… i can...      1
# 85  2 slimeballs in one yey lol grief in my heart ...      1
# 86  unlock the power of stock footage today noo sh...      1
# 87  hilarious please don39t give disney ideas so w...      1
#
# [88 rows x 6 columns]
# Size of Cleaned Positive Test Data: 88

# %% [markdown]
# ### Cleaning Negatives

# %%
# Create a new DataFrame with the cleaned text for negative
cleaned_neg_train_df = pd.DataFrame(columns=['video_id', 'title', 'description', 'url', 'comments', 'label'])
cleaned_neg_val_df = pd.DataFrame(columns=['video_id', 'title', 'description', 'url', 'comments', 'label'])
cleand_neg_test_df = pd.DataFrame(columns=['video_id', 'title', 'description', 'url', 'comments', 'label'])

# %%
cleaned_neg_train_df['video_id'] = neg_train_df['video_id']
cleaned_neg_train_df['url'] = neg_train_df['url']
cleaned_neg_train_df['label'] = neg_train_df['label']
cleaned_neg_train_df['title'] = neg_train_df['title'].apply(clean_text)
cleaned_neg_train_df['description'] = neg_train_df['description'].apply(clean_text)
cleaned_neg_train_df['comments'] = neg_train_df['comments'].apply(clean_text)

# %%
display(cleaned_neg_train_df)
print(f'Size of Cleaned negative Train Data: {len(cleaned_neg_train_df)}')
# Out:
#         video_id                                              title  \
# 0    NIAnOmqK2k0  yikes joe biden on why he was so irresponsible...
# 1    KDiUF9FG70Y           in the dark joe biden for president 2020
# 2    QXYzsFfvpLg  the future is yours joe bidens message to a ge...
# 3    PNKWjqW8kvI  biden gets confused again middle class didnt b...
# 4    iKKRU3ALjb0        republicans want a national ban on abortion
# ..           ...                                                ...
# 318  CQ-qQIKWYBw  “i want a safe america…” joe biden for preside...
# 319  rs3vQ49mfrY  im ign keanureeves johnwick redcarpet movies s...
# 320  T-9nFXNAE2I  i plan to work before the government is formed...
# 321  yJp5bEEO8uo                        elon musk warns as about ai
# 322  1qZORdDEc3Q  pm netanyahu today im going to make an unprece...
#
#                                            description  \
# 0                                                  nan
# 1    join our campaign joejoe’s twitter facebook in...
# 2    joe biden wants to make sure younger generatio...
# 3                               comments made on 41724
# 4    follow joejoe’s twitter facebook instagram bid...
# ..                                                 ...
# 318  donald trump looks at this violence and sees a...
# 319                                                nan
# 320  during an interview with the news agency ani p...
# 321                                                nan
# 322  today im going to make an unprecedented offer ...
#
#                                              url  \
# 0    https://www.youtube.com/watch?v=NIAnOmqK2k0
# 1    https://www.youtube.com/watch?v=KDiUF9FG70Y
# 2    https://www.youtube.com/watch?v=QXYzsFfvpLg
# 3    https://www.youtube.com/watch?v=PNKWjqW8kvI
# 4    https://www.youtube.com/watch?v=iKKRU3ALjb0
# ..                                           ...
# 318  https://www.youtube.com/watch?v=CQ-qQIKWYBw
# 319  https://www.youtube.com/watch?v=rs3vQ49mfrY
# 320  https://www.youtube.com/watch?v=T-9nFXNAE2I
# 321  https://www.youtube.com/watch?v=yJp5bEEO8uo
# 322  https://www.youtube.com/watch?v=1qZORdDEc3Q
#
#                                               comments  label
# 0    idk should i feel sad or mad at him quottheyqu...      0
# 1                                                  nan      0
# 2    it is about time gen z vote smarter in 2024 an...      0
# 3    what this is funny but dueable all these illeg...      0
# 4    fjb he39s to old and his brain doesn39t work k...      0
# ..                                                 ...    ...
# 318                                                nan      0
# 319  tan bello y humilde they can shoot their way i...      0
# 320  so nice for jhumla to trap people for vote ind...      0
# 321  how is ai possibly more dangerous than nukes i...      0
# 322  israel has started war on 3 fronts against ham...      0
#
# [323 rows x 6 columns]
# Size of Cleaned negative Train Data: 323

# %%
cleaned_neg_val_df = pd.DataFrame(columns=['video_id', 'title', 'description', 'url', 'comments', 'label'])
cleaned_neg_val_df = pd.DataFrame(columns=['video_id', 'title', 'description', 'url', 'comments', 'label'])
cleaned_neg_val_df = pd.DataFrame(columns=['video_id', 'title', 'description', 'url', 'comments', 'label'])

cleaned_neg_val_df['video_id'] = neg_val_df['video_id']
cleaned_neg_val_df['url'] = neg_val_df['url']
cleaned_neg_val_df['label'] = neg_val_df['label']
cleaned_neg_val_df['title'] = neg_val_df['title'].apply(clean_text)
cleaned_neg_val_df['description'] = neg_val_df['description'].apply(clean_text)
cleaned_neg_val_df['comments'] = neg_val_df['comments'].apply(clean_text)

# %%
display(cleaned_neg_val_df)
print(f'Size of Cleaned negative Val Data: {len(cleaned_neg_val_df)}')
# Out:
#        video_id                                              title  \
# 0   TyrHqJdgU7w  trump puts on heavy french accent to mock emma...
# 1   ISTu6JRtJTI  agenda47 ending the nightmare of the homeless ...
# 2   xzm_IlrpK_Y  ראש הממשלה נתניהו במערך 9900 אנחנו אומרים למחב...
# 3   R1DaTvQXwpY  impeached dhs sec alejandro mayorkas the south...
# 4   0-M20X5IoMM  president biden calls to end normal trade rela...
# 5   _I9vGD4j1_U  breaking joe biden says one of the classified ...
# 6   s_zva6pf3oA          donald trump predicts his victory in 1988
# 7   TpgKaaXuLAA  pm modi on indias robust international relatio...
# 8   YIWdxO2J-Tw    the top 5 moments of taylor swift’s life shorts
# 9   tUSroTovDqU  state of the union 2022 highlights from presid...
# 10  527-1MrJYUE  laxmi raai spotted at kromakay salon in juhu l...
# 11  63ze11S2VRQ  ram temple is a special occasion for 140 crore...
# 12  h9SzyjgQzU4  michelle obama speech at the democratic conven...
# 13  jUE4nSbqGw0  joe biden reads tweets joe biden for president...
# 14  uGJY3bs9dU4  president barack obama shows you how to vote b...
# 15  DKB4Mf5PVFY  trump being a sigma… alphamale masculinity fun...
# 39  https://www.youtube.com/watch?v=F8ajpQV-Fb4
# 40  https://www.youtube.com/watch?v=tc3yEJ3yBv8
# 41  https://www.youtube.com/watch?v=J4nr6NICkTw
# 42  https://www.youtube.com/watch?v=3KgGuOYUylE
# 43  https://www.youtube.com/watch?v=3vO1eXoRvUg
# 44  https://www.youtube.com/watch?v=tZOT-HzZy-Y
# 45  https://www.youtube.com/watch?v=1nW1S46_B-Y
#
#                                              comments  label
# 0   ماكرون فاشل this man is actually a comedian i ...      0
# 1   trump 2024 to save america and american famili...      0
# 2   أبو عبيدة الرايق باقي ماشفنا منك حتى شيكل باش ...      0
# 3   more hot air genital head is lying sure seems ...      0
# 4   hey joe don39t think about trying too get in a...      0
# 5   why isn39t he arrested for treason put him in ...      0
# 6   and he is one of those making fools fool trump...      0
# 7   long live modi ji jai naya bharat with modi ji...      0
# 8   i taylor swift they weren39t talking about fel...      0
# 9   the new slogan for the biden campaign and win ...      0
# 10  aunty i love you beautiful en logo ko ur koi k...      0
# 11  jai shri ram ĺong live modi ji jai naya bharat...      0
# 12                                                nan      0
# 13  biden makes huge mistakes all the time oh how ...      0
# 14                                                nan      0
# 15  men had enough exit the and last… don’t be a l...      0
# 16  votor fraudulent wins isis and 65k dollars of ...      0
# 17  trump shampoo what a joke why didn’t he just t...      0
# 18  wow his analogy and wording comes off as hurtf...      0
# 19                                                nan      0
# 20  sarcasm is a dangerous thing when there’s dish...      0
# 21  you great destroyed america and americans peop...      0
# 22  the best funny moment you absolutely have to s...      0
# 23  casting couch on xvideos wow she is really cut...      0
# 24  so sweet and real i love her sense of humor th...      0
# 25  rahul gandhi jindabad sir aap bahut great ho a...      0
# 26  filmes de gora novela agora mi gran admiración...      0
# 27                                                nan      0
# 28  those flashy looks are perfect for sg to portr...      0
# 29  keep working and speaking mr president joe bid...      0
# 30  joe biden is destroying america fjb thank you ...      0
# 31  the best president i have ever seen in my life...      0
# 32                                                nan      0
# 33  nananan brooooooo the sound effects i would be...      0
# 34                                                nan      0
# 35  movie name baar baar kapil sharma ke show me j...      0
# 36  you are my king david fjb well i am creating j...      0
# 37  252 zayn is literally looking like mafa don or...      0
# 38                                                nan      0
# 39  fluffy haaaaaaa i love your videos hands down ...      0
# 40  oh les cons ils l39ont cru il ne maîtrise déja...      0
# 41  excellent words long live modi ji jai naya bha...      0
# 42  yes god bless elon musk no he did not win it w...      0
# 43  shame shame shame may god open his heart to th...      0
# 44  what kind of a mom are you that don39t show yo...      0
# 45                                                nan      0
# Size of Cleaned negative Val Data: 46

# %%
cleaned_neg_test_df = pd.DataFrame(columns=['video_id', 'title', 'description', 'url', 'comments', 'label'])
cleaned_neg_test_df = pd.DataFrame(columns=['video_id', 'title', 'description', 'url', 'comments', 'label'])
cleaned_neg_test_df = pd.DataFrame(columns=['video_id', 'title', 'description', 'url', 'comments', 'label'])

cleaned_neg_test_df['video_id'] = neg_test_df['video_id']
cleaned_neg_test_df['url'] = neg_test_df['url']
cleaned_neg_test_df['label'] = neg_test_df['label']
cleaned_neg_test_df['title'] = neg_test_df['title'].apply(clean_text)
cleaned_neg_test_df['description'] = neg_test_df['description'].apply(clean_text)
cleaned_neg_test_df['comments'] = neg_test_df['comments'].apply(clean_text)
display(cleaned_neg_test_df)
# Out:
#        video_id                                              title  \
# 0   xAPIjhkXF-
# 3   https://www.youtube.com/watch?v=zOh1-WHonds
# 4   https://www.youtube.com/watch?v=zotkJwZ9PVY
# ..                                          ...
# 88  https://www.youtube.com/watch?v=SsVXDDQaQhM
# 89  https://www.youtube.com/watch?v=cKEZ4zlb7cU
# 90  https://www.youtube.com/watch?v=54cNlElopjE
# 91  https://www.youtube.com/watch?v=7-AAvESiRHU
# 92  https://www.youtube.com/watch?v=tqdSnr_0IvA
#
#                                              comments  label
# 0   over 150000 views thank you watch the full int...      0
# 1   very nice and jay shri krishna radhe and i lov...      0
# 2   fekuman ne war ruka di ab petrol diesel cng or...      0
# 3   shehnaz real pure soul bachcha shehnaazgill th...      0
# 4   i use to umpire baseball and this one guy was ...      0
# ..                                                ...    ...
# 88  quoti39ve thrown out these numbers therefore t...      0
# 89  free north korea dx satalite message ilov son ...      0
# 90  like and share the video if you love president...      0
# 91  youtube why are you paranoid of my comments do...      0
# 92  in europe there is not enough production capac...      0
#
# [93 rows x 6 columns]
# Size of Cleaned negative Test Data: 93

# %% [markdown]
# ### Change 'nan' to NaN

# %%
cleaned_neg_train_df = cleaned_neg_train_df.replace('nan', np.nan)
cleaned_neg_val_df = cleaned_neg_val_df.replace('nan', np.nan)
cleaned_neg_test_df = cleaned_neg_test_df.replace('nan', np.nan)

cleaned_pos_train_df = cleaned_pos_train_df.replace('nan', np.nan)
cleaned_pos_val_df = cleaned_pos_val_df.replace('nan', np.nan)
cleaned_pos_test_df = cleaned_pos_test_df.replace('nan', np.nan)

# %%
cleaned_neg_train_df
# Out:
#         video_id                                              title  \
# 0    NIAnOmqK2k0  yikes joe biden on why he was so irresponsible...
# 1    KDiUF9FG70Y           in the dark joe biden for president 2020
# 2    QXYzsFfvpLg  the future is yours joe bidens message to a ge...
# 3    PNKWjqW8kvI  biden gets confused again middle class didnt b...
# 4    iKKRU3ALjb0        republicans want a national ban on abortion
# ..           ...                                                ...
# 318  CQ-qQIKWYBw  “i want a safe america…” joe biden for preside...
# 319  rs3vQ49mfrY  im ign keanureeves johnwick redcarpet movies s...
# 320  T-9nFXNAE2I  i plan to work before the government is formed...
# 321  yJp5bEEO8uo                        elon musk warns as about ai
# 322  1qZORdDEc3Q  pm netanyahu today im going to make an unprece...
#
#                                            description  \
# 0                                                  NaN
# 1    join our campaign joejoe’s twitter facebook in...
# 2    joe biden wants to make sure younger generatio...
# 3                               comments made on 41724
# 4    follow joejoe’s twitter facebook instagram bid...
# ..                                                 ...
# 318  donald trump looks at this violence and sees a...
# 319                                                NaN
# 320  during an interview with the news agency ani p...
# 321                                                NaN
# 322  today im going to make an unprecedented offer ...
#
#                                              url  \
# 0    https://www.youtube.com/watch?v=NIAnOmqK2k0
# 1    https://www.youtube.com/watch?v=KDiUF9FG70Y
# 2    https://www.youtube.com/watch?v=QXYzsFfvpLg
# 3    https://www.youtube.com/watch?v=PNKWjqW8kvI
# 4    https://www.youtube.com/watch?v=iKKRU3ALjb0
# ..                                           ...
# 318  https://www.youtube.com/watch?v=CQ-qQIKWYBw
# 319  https://www.youtube.com/watch?v=rs3vQ49mfrY
# 320  https://www.youtube.com/watch?v=T-9nFXNAE2I
# 321  https://www.youtube.com/watch?v=yJp5bEEO8uo
# 322  https://www.youtube.com/watch?v=1qZORdDEc3Q
#
#                                               comments  label
# 0    idk should i feel sad or mad at him quottheyqu...      0
# 1                                                  NaN      0
# 2    it is about time gen z vote smarter in 2024 an...      0
# 3    what this is funny but dueable all these illeg...      0
# 4    fjb he39s to old and his brain doesn39t work k...      0
# ..                                                 ...    ...
# 318                                                NaN      0
# 319  tan bello y humilde they can shoot their way i...      0
# 320  so nice for jhumla to trap people for vote ind...      0
# 321  how is ai possibly more dangerous than nukes i...      0
# 322  israel has started war on 3 fronts against ham...      0
#
# [323 rows x 6 columns]

# %%
cleaned_neg_val_df
# Out:
#        video_id                                              title  \
# 0   TyrHqJdgU7w  trump puts on heavy french accent to mock emma...
# 1   ISTu6JRtJTI  agenda47 ending the nightmare of the homeless ...
# 2   xzm_IlrpK_Y  ראש הממשלה נתניהו במערך 9900 אנחנו אומרים למחב...
# 3   R1DaTvQXwpY  impeached dhs sec alejandro mayorkas the south...
# 4   0-M20X5IoMM  president biden calls to end normal trade rela...
# 5   _I9vGD4j1_U  breaking joe biden says one of the classified ...
# 6   s_zva6pf3oA          donald trump predicts his victory in 1988
# 7   TpgKaaXuLAA  pm modi on indias robust international relatio...
# 8   YIWdxO2J-Tw    the top 5 moments of taylor swift’s life shorts
# 9   tUSroTovDqU  state of the union 2022 highlights from presid...
# 10  527-1MrJYUE  laxmi raai spotted at kromakay salon in juhu l...
# 11  63ze11S2VRQ  ram temple is a special occasion for 140 crore...
# 12  h9SzyjgQzU4  michelle obama speech at the democratic conven...
# 13  jUE4nSbqGw0  joe biden reads tweets joe biden for president...
# 14  uGJY3bs9dU4  president barack obama shows you how to vote b...
# 15  DKB4Mf5PVFY  trump being a sigma… alphamale masculinity fun...
# 16  wswxrDiSiHI  obamas quick response to sarcastic republican ...
# 17  whnY9-ugr2w  trump sells bibles after years of touting his ...
# 18  t7xDb82TqiI              nvidias ceo on greatness jensen huang
# 19  0IHF-tFOEuI           indivisible joe biden for president 2020
# 20  TghKVxflpYo               donald trump impression of joe biden
# 21  s6Wjo9Civ_k  joe biden reading from his giant teleprompter ...
# 22  LYZTKTRLZ2U  rowan atkinson funny moments at top gear bbc t...
# 23  TivAwezqug4                            anushka sharma audition
# 24  GyQM0nD6hnw  sofía vergara addresses modern family reboot a...
# 25  1iBI3uW6lJA  i made this video last night at 1230am but my ...
# 26  vxOzffnZ-Ds  selena gomez on being a fashion newbie met gal...
# 27  Nc0ruRM7ws8  democratic national convention night one recap...
# 28  p1WD_rDHsFc     selena gomez goes behind the scenes with vogue
# 29  xudVnd6DTSQ                         democracy is on the ballot
# 30  B4K_OfMnTD0  kennedy family endorses pres biden in 2024 ele...
# 31  WIcoXT6MPjU  agenda47 protecting americans by taking on big...
# 32  aIa7VLtGIHc  president obama weeps over connecticut school ...
# 33  caqsDWJ-q8c                      snoop dogg was looking for me
# 34  MdHMwrjsK90  president bill clinton speech at the democrati...
# 35  PgJ_R1gjwTs  akshay kumar cant spell jacquelines name funny...
# 3   shehnaz real pure soul bachcha shehnaazgill th...      0
# 4   i use to umpire baseball and this one guy was ...      0
# ..                                                ...    ...
# 88  quoti39ve thrown out these numbers therefore t...      0
# 89  free north korea dx satalite message ilov son ...      0
# 90  like and share the video if you love president...      0
# 91  youtube why are you paranoid of my comments do...      0
# 92  in europe there is not enough production capac...      0
#
# [93 rows x 6 columns]

# %% [markdown]
# ### Moving Training Videos

# %%
def move_videos(src_dir, dest_dir, df):

    failed = list()

    # Create the "train" directory if it doesn't exist
    if not os.path.exists(dest_dir):
        os.makedirs(dest_dir)

    # Iterate over each row in the DataFrame
    for _, row in df.iterrows():
        video_id = row['video_id']
        
        # Construct the source and destination file paths
        source_path = os.path.join(src_dir, f"{video_id}.mp4")
        destination_path = os.path.join(dest_dir, f"{video_id}.mp4")
        
        # Check if the source video file exists
        if os.path.exists(source_path):
            # Copy the video file from the source to the destination
            shutil.copy2(source_path, destination_path)
            # print(f"Copied video {video_id}.mp4 to train directory.")
        else:
            print(f"Video {video_id}.mp4 not found in {src_dir} directory.")
            failed.append(video_id)

    if(len(failed) > 0):
        print(f'The following videos were not copied from {src_dir} to {dest_dir}')
        for vid in failed:
            print(vid)

# %%
# move pos training videos in train
move_videos(src_dir=pos_dir, dest_dir=train_dir, df=cleaned_pos_df)

# %%
# move neg training videos into train
move_videos(src_dir=neg_dir, dest_dir=train_dir, df=cleaned_neg_df)

# %%
print(f'Size of Negative Train: {len(cleaned_neg_df)}')
print(f'Size of Positive Train: {len(cleaned_pos_df)}')
print(f'Expect size of train: {len(cleaned_neg_df)+len(cleaned_pos_df)}')
print(f'Actual Size of Train: {len(os.listdir(train_dir))}')

# %%
# Assuming the 'cleaned_pos_df' and 'cleaned_neg_df' DataFrames are already defined

# Get the list of video files in the "train" directory
train_videos = [f for f in os.listdir(train_dir) if f.endswith(".mp4")]

# Extract the video IDs from the filenames in the "train" directory
train_video_ids = [os.path.splitext(f)[0] for f in train_videos]

# Concatenate the video IDs from both DataFrames
all_video_ids = pd.concat([cleaned_pos_df['video_id'], cleaned_neg_df['video_id']])

# Find the missing video IDs
missing_video_ids = all_video_ids.loc[~all_video_ids.isin(train_video_ids)]

# Print the missing video IDs
if len(missing_video_ids) > 0:
    print("Missing videos:")
    for video_id in missing_video_ids:
        print(video_id)
else:
    print("All videos were successfully copied.")
# Out:
# All videos were successfully copied.

# %%
# Find common video IDs using intersection()
common_video_ids = set(cleaned_pos_df['video_id']).intersection(set(cleaned_neg_df['video_id']))

# Print the common video IDs
if len(common_video_ids) > 0:
    print("Common video IDs:")
    for video_id in common_video_ids:
        print(video_id)
else:
    print("No common video IDs found.")
# Out:
# No common video IDs found.

# %% [markdown]
# ### Moving Validation Videos

# %%
pos_val_csv = os.path.join('../positive/validation.csv')
neg_val_csv = os.path.join('../negative/validation.csv')
pos_val_df = pd.read_csv(pos_val_csv)
neg_val_df = pd.read_csv(neg_val_csv)

# %%
val_df = pd.concat([pos_val_df, neg_val_df])
val_df[:20]
# Out:
#        video_id                                              title  \
# 0   zgX99Ne9mbI       What if politicians were teachers | DEEPFAKE
# 12  https://www.youtube.com/watch?v=jbvlVo8WLOU
# 13  https://www.youtube.com/watch?v=HCcIPLtDaeM
# 14  https://www.youtube.com/watch?v=320yMfXjHd4
# 15  https://www.youtube.com/watch?v=htYo_eAcwHQ
# 16  https://www.youtube.com/watch?v=8sCPZlJd4bk
# 17  https://www.youtube.com/watch?v=F4DrMNC23uw
# 18  https://www.youtube.com/watch?v=03wfJo3P2uE
# 19  https://www.youtube.com/watch?v=tOkfisapoRo
#
#                                              comments  label
# 0                        Kejriwal Real Lag Raha HAI 😉      1
# 1   Very cool.<sep>Omg is this really may I take t...      1
# 2   So, I bought her nothing 😂😂😂😂😂<sep>So fake... ...      1
# 3                                    love yr work man      1
# 4   She is beautiful and saucy! 😃❤<sep>everyone mu...      1
# 5   &quot;Hello this is Micheal Scott. I have an i...      1
# 6                                                 NaN      1
# 7   “Hey get away from my pasta”<sep>Bro looks mor...      1
# 8                                                 NaN      1
# 9   When you read the news all day and the world i...      1
# 10  If this doesn&#39;t make you feel something in...      1
# 11  Who is that lol<sep>He looks Asian now lmao<se...      1
# 12                                                NaN      1
# 13  Getting paid for nothing you can&#39;t blame E...      1
# 14  A script to die for !<sep>it was actualy funny...      1
# 15  So many people hate GW Bush, but i would reall...      1
# 16  Editing king<sep>Can u stream live or tell mor...      1
# 17                                                NaN      1
# 18  That is Michael backson<sep>wait this actually...      1
# 19  Smh lol 😅😅😅😅<sep>Can anyone explain the salad ...      1

# %%
cleaned_val_df = pd.DataFrame(columns=['video_id', 'title', 'description', 'url', 'cleaned_comments', 'label'])
cleaned_val_df['video_id'] = val_df['video_id']
cleaned_val_df['title'] = val_df['title']
cleaned_val_df['description'] = val_df['description'].apply(clean_text)
cleaned_val_df['url'] = val_df['url']
cleaned_val_df['label'] = val_df['label']
cleaned_val_df['cleaned_comments'] = val_df['comments'].apply(clean_text)
cleaned_val_df['cleaned_comments'] = cleaned_val_df['cleaned_comments'].replace('nan', np.nan)

# %%
cleaned_val_df[:20]
# Out:
#        video_id                                              title  \
# 0   zgX99Ne9mbI       What if politicians were teachers | DEEPFAKE
# 1   AcQdS9M7P5I                Ghost Caught On Traffic CCTV Camera
# 2   9J54CMpQO1A            Presidential Tales: My Wife Birthday...
# 3   pQGOJ5qPAS0  Get yourself Customised Synthetic Media Video ...
# 4   lDR2lmCO6iM                Scarlett Johansson eating Spaghetti
# 5   p89NkyNcpHo                     Ironman Recast - Michael Scott
# 6   v8uDCETeoj0            All in One #2 (DeepFake) TikTok #Shorts
# 7   0uGPxQHW4vY                        Spider-Man eating Spaghetti
# 8   4Qwyb-JZQuA  Men in Black / Kevin Hart (DeepFake) TikTok #S...
# 9   Xn1Tj_vHcjY                       THE THING starring Joe Biden
# 10  m6teLPZLMyI  C3PO's looks at his REAL FRIENDS before he die...
# 11  vyFzuGF_kmM  Kevin Spacey is back to acting - as Donald Tru...
# 12  jbvlVo8WLOU    Aladdin / Amber Heard (DeepFake) TikTok #Shorts
# 13  HCcIPLtDaeM  Donald Trump helps Elon Musk fire employees in...
# 38  https://www.youtube.com/watch?v=6ZYKbBDdMYQ              NaN      0
# 45  https://www.youtube.com/watch?v=1nW1S46_B-Y              NaN      0

# %%
cleaned_val_df.iloc[6, 4]
# Out:
# nan

# %% [markdown]
# ### Unsupervised Approaches to Generate Comments

# %% [markdown]
# #### Use Topic Modeling to Generate Comments for NaN comments

# %%
def topic_modeling_synthetic_comments(cleaned_df = None):
    # assuming 'comments' column is already preprocessed
    vectorizer = CountVectorizer(stop_words='english')
    doc_term_matrix = vectorizer.fit_transform(cleaned_df['comments'].dropna())

    # Train the LDA topic model
    lda_model = LatentDirichletAllocation(n_components=10, random_state=42)
    lda_model.fit(doc_term_matrix)

    # Generate synthetic comments for videos without comments
    for index, row in cleaned_df[cleaned_df['comments'].isna()].iterrows():
        video_label = row['label']
        video_title = row['title']
        video_description = row['description']  # Assuming 'description' column contains video descriptions
        
        # Combine video title and description
        video_metadata = f"{video_title} {video_description}"
        
        # Predict the topic distribution for the video
        topic_prob = lda_model.transform(vectorizer.transform([video_metadata]))[0]
        top_topics = topic_prob.argsort()[-3:][::-1]
        
        # Generate synthetic comments
        synthetic_comment = []
        for topic_id in top_topics:
            top_words = [vectorizer.get_feature_names_out()[i] for i in lda_model.components_[topic_id].argsort()[-5:][::-1]]
            synthetic_comment.extend(top_words)
        
        synthetic_comment = ' '.join(synthetic_comment)
        cleaned_df.at[index, 'comments'] = synthetic_comment

# %% [markdown]
# #### Use Sentiment Analysis

# %%
def sentiment_analysis_synthetic_comments(cleaned_df=None):

    # assuming 'comments' column is already preprocessed
    vectorizer = TfidfVectorizer()
    comment_matrix = vectorizer.fit_transform(cleaned_df['comments'].dropna())

    # Perform sentiment analysis on the available comments
    sentiment_scores = []
    for comment in cleaned_df['comments'].dropna():
        sentiment = TextBlob(comment).sentiment.polarity
        sentiment_scores.append(sentiment)

    cleaned_df['sentiment'] = pd.Series(sentiment_scores)

    # Generate synthetic comments for videos without comments
    for index, row in cleaned_df[cleaned_df['comments'].isna()].iterrows():
        video_label = row['label']
        video_title = row['title']
        video_description = row['description']
        
        # Combine video title and description
        video_metadata = f"{video_title} {video_description}"
        
        # Find similar videos based on video metadata
        metadata_vector = vectorizer.transform([video_metadata])
        similarity_scores = cosine_similarity(metadata_vector, comment_matrix)
        similar_indices = similarity_scores.argsort()[0][-5:][::-1]
        
        # Get the sentiment scores of similar videos
        similar_sentiments = cleaned_df.iloc[similar_indices]['sentiment']
        
        # Determine the sentiment for the video based on similar videos and its label
        if video_label == 1:  # Deepfake video
            sentiment = similar_sentiments.min()
        else:  # Non-deepfake video
            sentiment = similar_sentiments.max()
        
        # Generate synthetic comment based on sentiment and video characteristics
        if sentiment > 0:
            synthetic_comment = f"This video about {video_title} seems interesting. {video_description}"
        elif sentiment < 0:
            synthetic_comment = f"I'm not sure about the content of this video on {video_title}. {video_description}"
        else:
            synthetic_comment = f"The video '{video_title}' discusses {video_description}."
        
        cleaned_df.at[index, 'comments'] = synthetic_comment

# %% [markdown]
# #### Collaborative Filtering

# %%
def collab_filter_synth_comments(cleaned_df=None):

    # assuming 'comments' column is already preprocessed
    vectorizer = TfidfVectorizer()
    comment_matrix = vectorizer.fit_transform(cleaned_df['comments'].dropna())

    # Perform dimensionality reduction using Truncated SVD
    svd = TruncatedSVD(n_components=100)
    reduced_matrix = svd.fit_transform(comment_matrix)

    # Generate synthetic comments for videos without comments
    for index, row in cleaned_df[cleaned_df['comments'].isna()].iterrows():
        video_label = row['label']
        video_title = row['title']
        video_description = row['description']
        
        # Combine video title and description
        video_metadata = f"{video_title} {video_description}"
        
        # Find similar videos based on video metadata
        metadata_vector = vectorizer.transform([video_metadata])
        reduced_metadata_vector = svd.transform(metadata_vector)
        similarity_scores = cosine_similarity(reduced_metadata_vector, reduced_matrix)
        similar_indices = similarity_scores.argsort()[0][-5:][::-1]
        
        # Get the comments from similar videos
        similar_comments = cleaned_df.iloc[similar_indices]['comments']
        
        # Filter out missing comments
        valid_comments = similar_comments.dropna()
        
        # Generate synthetic comment by combining valid comments from similar videos
        if not valid_comments.empty:
            synthetic_comment = ' '.join(valid_comments)
        else:
            synthetic_comment = "No relevant comments found."
        
        cleaned_df.at[index, 'comments'] = synthetic_comment

# %%
collab_filter_synth_comments(cleaned_neg_train_df)
collab_filter_synth_comments(cleaned_neg_val_df)
collab_filter_synth_comments(cleaned_neg_test_df)

collab_filter_synth_comments(cleaned_pos_train_df)
collab_filter_synth_comments(cleaned_pos_val_df)
collab_filter_synth_comments(cleaned_pos_test_df)

# %%
print('Negatives:')
nan_count = cleaned_neg_train_df['comments'].isna().sum()
print(f'Number of NaN in cleaned_neg_train_df: {nan_count}')

nan_count = cleaned_neg_val_df['comments'].isna().sum()
print(f'Number of NaN in cleaned_neg_val_df: {nan_count}')

nan_count = cleaned_neg_test_df['comments'].isna().sum()
print(f'Number of NaN in cleaned_neg_test_df: {nan_count}')

print('\nPositives:')
nan_count = cleaned_pos_train_df['comments'].isna().sum()
print(f'Number of NaN in cleaned_pos_train_df: {nan_count}')

nan_count = cleaned_pos_val_df['comments'].isna().sum()
print(f'Number of NaN in cleaned_pos_val_df: {nan_count}')

nan_count = cleaned_pos_test_df['comments'].isna().sum()
print(f'Number of NaN in cleaned_pos_test_df: {nan_count}')
# Out:
# Negatives:
# Number of NaN in cleaned_neg_train_df: 0
# Number of NaN in cleaned_neg_val_df: 0
# Number of NaN in cleaned_neg_test_df: 0
#
# Positives:
# Number of NaN in cleaned_pos_train_df: 0
# Number of NaN in cleaned_pos_val_df: 0
# Number of NaN in cleaned_pos_test_df: 0

# %% [markdown]
# ### Move Training data to file

# %%
def delete_folder_contents(path):
    for filename in os.listdir(path):
        file_path = os.path.join(path, filename)
        try:
            if os.path.isfile(file_path) or os.path.islink(file_path):
                os.unlink(file_path)  # Remove file or link
            elif os.path.isdir(file_path):
                shutil.rmtree(file_path)  # Remove directory and all its contents
        except Exception as e:
            print(f'Failed to delete {file_path}. Reason: {e}')

# %%
delete_folder_contents(train_dir)
delete_folder_contents(val_dir)
delete_folder_contents(test_dir)

# %%
def move_videos(src_dir, dest_dir, df):

    failed = list()

    # Create the "train" directory if it doesn't exist
    if not os.path.exists(dest_dir):
        os.makedirs(dest_dir)

    # Iterate over each row in the DataFrame
    for _, row in df.iterrows():
        video_id = row['video_id']
        
        # Construct the source and destination file paths
        source_path = os.path.join(src_dir, f"{video_id}.mp4")
        destination_path = os.path.join(dest_dir, f"{video_id}.mp4")
        
        # Check if the source video file exists
        if os.path.exists(source_path):
            # Copy the video file from the source to the destination
            shutil.copy2(source_path, destination_path)
            # print(f"Copied video {video_id}.mp4 to train directory.")
        else:
            print(f"Video {video_id}.mp4 not found in {src_dir} directory.")
            failed.append(video_id)

    if(len(failed) > 0):
        print(f'The following videos were not copied from {src_dir} to {dest_dir}')
        for vid in failed:
            print(vid)

# %%
# create training set
train_df = pd.concat([cleaned_pos_train_df, cleaned_neg_train_df])
# create validation set
val_df = pd.concat([cleaned_pos_val_df, cleaned_neg_val_df])
# create test set
test_df = pd.concat([cleaned_pos_test_df, cleaned_neg_test_df])

# %%
# training set
num_pos_train = len(cleaned_pos_train_df)
num_neg_train = len(cleaned_neg_train_df)
num_train = len(train_df)
print(f'Expected Size of Training set: {num_neg_train + num_pos_train}')
print(f'Actual Size of Training Set: {num_train}')
# Out:
# Expected Size of Training set: 627
# Actual Size of Training Set: 627

# %%
# validation set
num_pos_val = len(cleaned_pos_val_df)
num_neg_val = len(cleaned_neg_val_df)
num_val = len(val_df)
print(f'Expected Size of Validation set: {num_pos_val + num_neg_val}')
print(f'Actual Size of Validation Set: {num_val}')
# Out:
# Expected Size of Validation set: 89
# Actual Size of Validation Set: 89

# %%
# test set
num_pos_test = len(cleaned_pos_test_df)
num_neg_test = len(cleaned_neg_test_df)
num_test = len(test_df)
print(f'Expected Size of Test set: {num_pos_test + num_neg_test}')
print(f'Actual Size of Test Set: {num_test}')
# Out:
# Expected Size of Test set: 181
# Actual Size of Test Set: 181

# %%
# move pos training videos in train
move_videos(src_dir=pos_dir, dest_dir=train_dir, df=cleaned_pos_df)

# %%
# move neg training videos into train
move_videos(src_dir=neg_dir, dest_dir=train_dir, df=cleaned_neg_df)

# %%
print(f'Size of Negative Train: {len(cleaned_neg_df)}')
print(f'Size of Positive Train: {len(cleaned_pos_df)}')
print(f'Expect size of train: {len(cleaned_neg_df)+len(cleaned_pos_df)}')
print(f'Actual Size of Train: {len(os.listdir(train_dir))}')

# %%
# Assuming the 'cleaned_pos_df' and 'cleaned_neg_df' DataFrames are already defined

# Get the list of video files in the "train" directory
train_videos = [f for f in os.listdir(train_dir) if f.endswith(".mp4")]

# Extract the video IDs from the filenames in the "train" directory
train_video_ids = [os.path.splitext(f)[0] for f in train_videos]

# Concatenate the video IDs from both DataFrames
all_video_ids = pd.concat([cleaned_pos_df['video_id'], cleaned_neg_df['video_id']])

# Find the missing video IDs
missing_video_ids = all_video_ids.loc[~all_video_ids.isin(train_video_ids)]

# Print the missing video IDs
if len(missing_video_ids) > 0:
    print("Missing videos:")
    for video_id in missing_video_ids:
        print(video_id)
else:
    print("All videos were successfully copied.")
# Out:
# All videos were successfully copied.

# %%
# Find common video IDs using intersection()
common_video_ids = set(cleaned_pos_df['video_id']).intersection(set(cleaned_neg_df['video_id']))

# Print the common video IDs
if len(common_video_ids) > 0:
    print("Common video IDs:")
    for video_id in common_video_ids:
        print(video_id)
else:
    print("No common video IDs found.")
# Out:
# No common video IDs found.
